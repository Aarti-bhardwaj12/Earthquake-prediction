# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../Data/earthquake_data.csv')
data.head()
# Out:
#                                           title  magnitude         date_time  \
# 0  M 7.0 - 18 km SW of Malango, Solomon Islands        7.0  22-11-2022 02:03
# 1      M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9  18-11-2022 13:37
# 2                                      M 7.0 -         7.0  12-11-2022 07:09
# 3           M 7.3 - 205 km ESE of Neiafu, Tonga        7.3  11-11-2022 10:48
# 4                                      M 6.6 -         6.6  09-11-2022 10:14
#
#    cdi  mmi  alert  tsunami  sig net  nst   dmin   gap magType    depth  \
# 0    8    7  green        1  768  us  117  0.509  17.0     mww   14.000
# 1    4    4  green        0  735  us   99  2.229  34.0     mww   25.000
# 2    3    3  green        1  755  us  147  3.125  18.0     mww  579.000
# 3    5    5  green        1  833  us  149  1.865  21.0     mww   37.000
# 4    0    2  green        1  670  us  131  4.998  27.0     mww  624.464
#
#    latitude  longitude                  location continent          country
# 0   -9.7963    159.596  Malango, Solomon Islands   Oceania  Solomon Islands
# 1   -4.9559    100.738       Bengkulu, Indonesia       NaN              NaN
# 2  -20.0508   -178.346                       NaN   Oceania             Fiji
# 3  -19.2918   -172.129             Neiafu, Tonga       NaN              NaN
# 4  -25.5948    178.278                       NaN       NaN              NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      782 non-null    object
#  1   magnitude  782 non-null    float64
#  2   date_time  782 non-null    object
#  3   cdi        782 non-null    int64
#  4   mmi        782 non-null    int64
#  5   alert      415 non-null    object
#  6   tsunami    782 non-null    int64
#  7   sig        782 non-null    int64
#  8   net        782 non-null    object
#  9   nst        782 non-null    int64
#  10  dmin       782 non-null    float64
#  11  gap        782 non-null    float64
#  12  magType    782 non-null    object
#  13  depth      782 non-null    float64
#  14  latitude   782 non-null    float64
#  15  longitude  782 non-null    float64
#  16  location   777 non-null    object
#  17  continent  206 non-null    object
#  18  country    484 non-null    object
# dtypes: float64(6), int64(5), object(8)
# memory usage: 116.2+ KB

# %%
data.describe().transpose()
# Out:
#            count        mean         std       min        25%       50%  \
# magnitude  782.0    6.941125    0.445514    6.5000    6.60000    6.8000
# cdi        782.0    4.333760    3.169939    0.0000    0.00000    5.0000
# mmi        782.0    5.964194    1.462724    1.0000    5.00000    6.0000
# tsunami    782.0    0.388747    0.487778    0.0000    0.00000    0.0000
# sig        782.0  870.108696  322.465367  650.0000  691.00000  754.0000
# nst        782.0  230.250639  250.188177    0.0000    0.00000  140.0000
# dmin       782.0    1.325757    2.218805    0.0000    0.00000    0.0000
# gap        782.0   25.038990   24.225067    0.0000   14.62500   20.0000
# depth      782.0   75.883199  137.277078    2.7000   14.00000   26.2950
# latitude   782.0    3.538100   27.303429  -61.8484  -14.59560   -2.5725
# longitude  782.0   52.609199  117.898886 -179.9680  -71.66805  109.4260
#
#                 75%        max
# magnitude    7.1000     9.1000
# cdi          7.0000     9.0000
# mmi          7.0000     9.0000
# tsunami      1.0000     1.0000
# sig        909.7500  2910.0000
# nst        445.0000   934.0000
# dmin         1.8630    17.6540
# gap         30.0000   239.0000
# depth       49.7500   670.8100
# latitude    24.6545    71.6312
# longitude  148.9410   179.6620

# %%
data.isnull().sum()
# Out:
# title          0
# magnitude      0
# date_time      0
# cdi            0
# mmi            0
# alert        367
# tsunami        0
# sig            0
# net            0
# nst            0
# dmin           0
# gap            0
# magType        0
# depth          0
# latitude       0
# longitude      0
# location       5
# continent    576
# country      298
# dtype: int64

# %%
features = ["magnitude", "depth", "cdi", "mmi", "sig"]
target = "alert"
data = data[features + [target]]
data.head(10)
# Out:
#    magnitude    depth  cdi  mmi   sig   alert
# 0        7.0   14.000    8    7   768   green
# 1        6.9   25.000    4    4   735   green
# 2        7.0  579.000    3    3   755   green
# 3        7.3   37.000    5    5   833   green
# 4        6.6  624.464    0    2   670   green
# 5        7.0  660.000    4    3   755   green
# 6        6.8  630.379    1    3   711   green
# 7        6.7   20.000    7    6   797   green
# 8        6.8   20.000    8    7  1179  yellow
# 9        7.6   26.943    9    8  1799  yellow

# %%
plt.figure(figsize = (6,12))
plt.pie(x = data[target].value_counts(), labels = ['blue','orange','green','red'], autopct = '%.2f')
plt.title("Distribution of values in alert column")
plt.legend()
plt.show()

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 415 entries, 0 to 507
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  415 non-null    float64
#  1   depth      415 non-null    float64
#  2   cdi        415 non-null    int64
#  3   mmi        415 non-null    int64
#  4   sig        415 non-null    int64
#  5   alert      415 non-null    object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 22.7+ KB

# %%
data = data.astype({'cdi': 'int8', 'mmi': 'int8', 'sig': 'int8', 'depth': 'int16', 'alert': 'category'})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 415 entries, 0 to 507
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   magnitude  415 non-null    float64
#  1   depth      415 non-null    int16
#  2   cdi        415 non-null    int8
#  3   mmi        415 non-null    int8
#  4   sig        415 non-null    int8
#  5   alert      415 non-null    category
# dtypes: category(1), float64(1), int16(1), int8(3)
# memory usage: 9.1 KB

# %%
data[target].value_counts().plot(kind='bar', title='Count (target)', color=['green', 'yellow', 'orange', 'red']);

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\aarti\AppData\Local\Programs\Python\Python311\python.exe

# %%
import pkg_resources
print([pkg.key for pkg in pkg_resources.working_set])
# Out:
# ['notebook', 'jupyterlab', 'jupyter', 'fsspec', 'pytz', 'tzdata', 'certifi', 'regex', 'jsonschema-specifications', 'pywin32', 'setuptools', 'pyzmq', 'attrs', 'flatbuffers', 'pip', 'webcolors', 'packaging', 'argon2-cffi', 'argon2-cffi-bindings', 'isoduration', 'libclang', 'rich', 'pillow', 'ipython', 'jupyter-client', 'click', 'ipywidgets', 'nbconvert', 'overrides', 'psutil', 'ipykernel', 'jupyter-console', 'tornado', 'bleach', 'pyyaml', 'plotly', 'protobuf', 'traitlets', 'nbformat', 'jupyter-core', 'decorator', 'tqdm', 'fonttools', 'transformers', 'jsonschema', 'beautifulsoup4', 'typing-extensions', 'anyio', 'platformdirs', '-upyterlab', 'widgetsnbextension', 'filelock', 'h5py', 'matplotlib', 'idna', 'keras', 'nltk', 'markdown', 'threadpoolctl', 'networkx', 'charset-normalizer', 'opt-einsum', 'python-json-logger', 'pyparsing', 'jinja2', 'mistune', 'werkzeug', 'prompt-toolkit', 'jupyterlab-widgets', 'markupsafe', 'asttokens', 'jsonpointer', 'markdown-it-py', 'termcolor', 'xgboost', 'requests', 'jupyterlab-server', 'pycparser', 'fastjsonschema', 'pygments', 'tensorboard', 'tensorflow', 'tf-keras', 'babel', 'jupyter-server', 'types-python-dateutil', 'python-dateutil', 'torch', 'soupsieve', 'urllib3', 'jupyter-lsp', 'pandas', 'absl-py', 'executing', 'numpy', 'pywinpty', 'async-lru', 'grpcio', 'narwhals', 'wrapt', 'cffi', 'six', 'scipy', 'sympy', 'debugpy', 'send2trash', 'websocket-client', 'astunparse', 'scikit-learn', 'nest-asyncio', 'fqdn', 'pandocfilters', 'kiwisolver', 'joblib', 'tinycss2', 'contourpy', 'sniffio', 'arrow', 'mpmath', 'uri-template', 'ipython-pygments-lexers', 'hf-xet', 'httpcore', 'wheel', 'referencing', 'tensorflow-io-gcs-filesystem', 'huggingface-hub', 'httpx', 'rpds-py', 'prometheus-client', 'tokenizers', 'jedi', 'terminado', 'optree', 'h11', 'seaborn', 'cycler', 'jupyter-events', 'json5', 'nbclient', 'parso', 'tensorboard-data-server', 'defusedxml', 'stack-data', 'gast', 'jupyter-server-terminals', 'safetensors', 'ml-dtypes', 'webencodings', 'colorama', 'jupyterlab-pygments', 'wcwidth', 'notebook-shim', 'pure-eval', 'comm', 'google-pasta', 'matplotlib-inline', 'rfc3339-validator', 'mdurl', 'rfc3986-validator', 'namex']

# %%
# !{sys.executable} -m pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\aarti\appdata\local\programs\python\python311\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\aarti\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (2.1.3)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\aarti\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\aarti\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\aarti\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\aarti\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\aarti\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (3.6.0)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\aarti\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\aarti\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\aarti\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import os
os.environ["LOKY_MAX_CPU_COUNT"] = "4"  # Replace 4 with the number of physical cores you have

X = data[features]
y = data[target]

X = X.loc[:, ~X.columns.duplicated()]

sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, y)

y_res.value_counts().plot(kind='bar', title='Count (target)', color=['green', 'orange', 'red', 'yellow']);

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.preprocessing import LabelEncoder

# Example DataFrame (Ensure the column exists)
data = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1],
    'C': [2, 3, 4, 5, 6],
    'Color': ['red', 'blue', 'green', 'yellow', 'black']  # Ensure 'Color' exists
})

# Check if 'Color' column exists
if 'Color' in data.columns:
    label_encoder = LabelEncoder()
    data['Color'] = label_encoder.fit_transform(data['Color'])

# Drop non-numeric columns before correlation calculation
numeric_data = data.select_dtypes(include=['number'])

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_data.corr(), annot=True, fmt=".2f")
plt.show()

# %%
models = []
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
dt_pred = dt.predict(X_test)
print(accuracy_score(dt_pred,y_test)*100)
print(classification_report(dt_pred, y_test))
sns.heatmap(confusion_matrix(dt_pred, y_test), annot = True)
plt.plot()
# Out:
# 88.07692307692308
#               precision    recall  f1-score   support
#
#        green       0.79      0.89      0.84        61
#       orange       0.88      0.88      0.88        73
#          red       0.94      0.97      0.95        62
#       yellow       0.93      0.80      0.86        64
#
#     accuracy                           0.88       260
#    macro avg       0.88      0.88      0.88       260
# weighted avg       0.88      0.88      0.88       260
# []

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_pred = knn.predict(X_test)
print(accuracy_score(knn_pred, y_test)*100)
print(classification_report(knn_pred, y_test))
sns.heatmap(confusion_matrix(knn_pred, y_test), annot = True)
plt.plot()
# Out:
# 89.23076923076924
#               precision    recall  f1-score   support
#
#        green       0.78      0.96      0.86        55
#       orange       0.95      0.83      0.88        83
#          red       0.92      0.95      0.94        62
#       yellow       0.93      0.85      0.89        60
#
#     accuracy                           0.89       260
#    macro avg       0.89      0.90      0.89       260
# weighted avg       0.90      0.89      0.89       260
# []

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_pred = rf.predict(X_test)
print(accuracy_score(rf_pred, y_test)*100)
print(classification_report(rf_pred, y_test))
sns.heatmap(confusion_matrix(rf_pred, y_test), annot = True)
plt.plot()
# Out:
# 91.15384615384615
#               precision    recall  f1-score   support
#
#        green       0.82      0.93      0.88        60
#       orange       0.95      0.91      0.93        76
#          red       0.95      0.98      0.97        62
#       yellow       0.93      0.82      0.87        62
#
#     accuracy                           0.91       260
#    macro avg       0.91      0.91      0.91       260
# weighted avg       0.91      0.91      0.91       260
# []

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(random_state=42)
gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
gb_pred = gb.predict(X_test)
print(accuracy_score(gb_pred, y_test)*100)
print(classification_report(gb_pred, y_test))
sns.heatmap(confusion_matrix(gb_pred, y_test), annot = True)
plt.plot()
# Out:
# 92.6923076923077
#               precision    recall  f1-score   support
#
#        green       0.82      0.93      0.88        60
#       orange       0.99      0.91      0.95        79
#          red       0.97      0.98      0.98        63
#       yellow       0.93      0.88      0.90        58
#
#     accuracy                           0.93       260
#    macro avg       0.93      0.93      0.93       260
# weighted avg       0.93      0.93      0.93       260
# []
